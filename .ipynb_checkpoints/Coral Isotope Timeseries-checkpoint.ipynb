# %% [markdown]
# # Coral Isotope Timeseries

# %%
# Load packages
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
import numpy as np
import pandas as pd
pd.set_option('max_rows', 6)
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import cmocean.cm as cmo
import csv
import statsmodels.api as sm
from scipy import stats

# mpl.rcParams['mathtext.fontset'] = 'cm'
# mpl.rcParams['mathtext.rm'] = 'serif'

x = "Year CE"
phe = r'$\mathrm{\delta}^{15}$N Phe ('u"\u2030)"
eaa_neaa = ['Phe', 'Thr', 'Ile', 'Leu', 'Val', 'Asx', 'Glx', 'Pro', 'Ala', 'Ser', 'Gly'] # For Essential/Non-Essential ordering
tr_srcaa = ['Glu', 'Asp', 'Ala', 'Ile', 'Leu', 'Pro', 'Val', 'Gly', 'Ser', 'Lys', 'Tyr', 'Phe', 'Thr'] # For Trophic/Source AA ordering
n = r'$\mathrm{\delta}^{15}$N ['u"\u2030]"
c = r'$\mathrm{\delta}^{13}$C ['u"\u2030]"
deg = u'SST [\u00B0C]'

# Import data
path1 = '~/Documents/GitHub/data/schiff_bulk_years_09-04-2019.csv'

df = pd.read_csv(path1, comment = '#')
df.rename(columns={"d15n.vs.air": "d15n", "d13c.vs.vpdb": "d13c", "linear.ad" : "yrAD", "coral.id" : "coral"}, inplace = True)

# Round yrAD column to make things easier
df.yrAD = df.yrAD.round(0)

df_stet = df[df.coral == 'stet-4904-bc1-d2']
df_jack4907 = df[df.coral == 'jack-4907-bc1-d3']
df_sav = df[df.coral == 'sav-4902-bc1-unk']
df_jack4684 = df[df.coral == 'jack-4684-bc-unk']
df_jack4686 = df[df.coral == 'jack-4686-bc-d1-t1']

print(df)
# Out:
#                  coral sampler  sample.no.  distance..mm.  d15n   d13c  \
# 0     jack-4907-bc1-d3    john           1          0.032  9.43 -15.24
# 1     jack-4907-bc1-d3    john           2          0.064  9.78 -15.38
# 2     jack-4907-bc1-d3    john           3          0.096  9.41 -15.14
# ...                ...     ...         ...            ...   ...    ...
# 1102  sav-4902-bc1-unk    usgs         143         44.040  7.60 -17.86
# 1103  sav-4902-bc1-unk    usgs         144         44.450  7.48 -18.76
# 1104  sav-4902-bc1-unk    usgs         145         44.920  8.52 -17.44
#
#      treatment  perc.n  perc.c  cn.ratio       machine   X  X.1    yrAD
# 0            a     NaN     NaN       2.3  deltaplus xp NaN  NaN  1228.0
# 1            a     NaN     NaN       NaN           NaN NaN  NaN  1201.0
# 2            a     NaN     NaN       2.7  deltaplus xp NaN  NaN  1175.0
# ...        ...     ...     ...       ...           ...  ..  ...     ...
# ...

# %% [markdown]
# ### Bulk d15N

# %%
# Recent history, bulk d15N
fig = plt.figure()
ax = fig.add_subplot(111)

plt.plot('yrAD', 'd15n', data=df_stet,
         color='#e66101', label = 'Stetson Banks', markeredgecolor = 'black', markersize = 8)
plt.plot('yrAD', 'd15n', data=df_jack4684, 
         color='#5e3c99', label = 'Stetson Banks', markeredgecolor = 'black', markersize = 8)

# Rolling mean



# Draw x label
ax.xaxis.set_label_position('top') # this moves the label to the top
ax.xaxis.set_ticks_position('top') # this moves the ticks to the top
ax.set_xlabel("Year CE")

# Draw y label
ax.set_ylim(ax.get_ylim())
ax.set_ylabel(n)
# Out:
# Text(0, 0.5, '$\\mathrm{\\delta}^{15}$N [‰]')

# %%
# Ancient d15N changes

fig = plt.figure()
ax = fig.add_subplot(111)

plt.plot('yrAD', 'd15n', data=df_sav,
         color='#a6611a', label = 'Stetson Banks', markeredgecolor = 'black', markersize = 8)
plt.plot('yrAD', 'd15n', data=df_jack4907, 
         color='#018571', label = 'Stetson Banks', markeredgecolor = 'black', markersize = 8)

# Draw x label
ax.xaxis.set_label_position('top') # this moves the label to the top
ax.xaxis.set_ticks_position('top') # this moves the ticks to the top
ax.set_xlabel("Year CE")

# Draw y label
ax.set_ylim(ax.get_ylim())
ax.set_ylabel(n)
# Out:
# Text(0, 0.5, '$\\mathrm{\\delta}^{15}$N (‰)')

# %% [markdown]
# ### Bulk d13C

# %%
# Recent history, bulk d15N
fig = plt.figure()
ax = fig.add_subplot(111)

plt.plot('yrAD', 'd13c', data=df_stet,
         color='#e66101', label = 'Stetson Banks', markeredgecolor = 'black', markersize = 8)
# plt.plot('yrAD', 'd13c', data=df_jack4684, 
#          color='#5e3c99', label = 'Stetson Banks', markeredgecolor = 'black', markersize = 8)

# Rolling mean



# Draw x label
ax.xaxis.set_label_position('top') # this moves the label to the top
ax.xaxis.set_ticks_position('top') # this moves the ticks to the top
ax.set_xlabel("Year CE")

# Draw y label
ax.set_ylim(ax.get_ylim())
ax.set_ylabel(c)
# Out:
# Text(0, 0.5, '$\\mathrm{\\delta}^{13}$C (‰)')

# %%
# Ancient d13C changes

fig = plt.figure()
ax = fig.add_subplot(111)

plt.plot('yrAD', 'd13c', data=df_sav,
         color='#a6611a', markeredgecolor = 'black', markersize = 8)
plt.plot('yrAD', 'd13c', data=df_jack4907, 
         color='#018571', markeredgecolor = 'black', markersize = 8)

# Draw x label
ax.xaxis.set_label_position('top') # this moves the label to the top
ax.xaxis.set_ticks_position('top') # this moves the ticks to the top
ax.set_xlabel("Year CE")

# Draw y label
ax.set_ylim(ax.get_ylim())
ax.set_ylabel(c)
# Out:
# Text(0, 0.5, '$\\mathrm{\\delta}^{13}$C [‰]')

# %% [markdown]
# ## Bulk d13C and d15N coupling

# %% [markdown]
# ### Stetson-4904 BC1

# %%
plt.subplot(2, 1, 1)
plt.plot('yrAD', 'd13c', data=df_stet,
         color='#e66101', label = 'Stetson Banks', marker = "o", markersize = 4)
plt.title('Stetson-4904 BC1')
plt.ylabel(c)

plt.subplot(2, 1, 2)
plt.plot('yrAD', 'd15n', data=df_stet,
         color='#e66101', label = 'Stetson Banks', markeredgecolor = 'black', markersize = 4)
# plt.title('Stetson-4904 BC1')
plt.ylabel(n)

plt.show()

# %%
fig, axs = plt.subplots(2, sharex=True)
axs[0].plot('yrAD', 'd15n', data=df_stet,
         color='#e66101', marker = "o", markersize = 4)
axs[0].set_title('Stetson-4904 BC1')
axs[0].set_ylabel(n)
axs[1].plot('yrAD', 'd13c', data=df_stet,
         color='#e66101', marker = "o", markersize = 4)
axs[1].set_ylabel(c)
axs[1].set_xlabel('Year CE')
# Out:
# Text(0.5, 0, 'Year CE')

# %% [markdown]
# ### Jacksonville-4907 BC1

# %%
plt.subplot(2, 1, 1)
plt.plot('yrAD', 'd13c', data=df_jack4907,
         color='#018571', markeredgecolor = 'black', markersize = 8)
plt.title('Jacksonville-4907 BC1')
plt.ylabel(c)

plt.subplot(2, 1, 2)
plt.plot('yrAD', 'd15n', data=df_jack4907,
         color='#018571', markeredgecolor = 'black', markersize = 8)
# plt.title('Stetson-4904 BC1')
plt.ylabel(n)

plt.show()

# %%
fig, axs = plt.subplots(2, sharex=True)
axs[0].plot('yrAD', 'd15n', data=df_jack4907, marker = "o",
         color='#018571', markersize = 4)
axs[0].set_title('Jacksonville-4907 BC1')
axs[0].set_ylabel(n)
axs[1].plot('yrAD', 'd13c', data=df_jack4907, marker = "o",
         color='#018571', markersize = 4)
axs[1].set_ylabel(c)
axs[1].set_xlabel('Year CE')
# Out:
# Text(0.5, 0, 'Year CE')

# %%
X = df_jack4907["d15n"]
y = df_jack4907["d13c"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   d13c   R-squared (uncentered):                   0.992
# Model:                            OLS   Adj. R-squared (uncentered):              0.992
# Method:                 Least Squares   F-statistic:                          4.003e+04
# Date:                Sat, 07 Dec 2019   Prob (F-statistic):                        0.00
# Time:                        10:08:37   Log-Likelihood:                         -552.94
# No. Observations:                 318   AIC:                                      1108.
# Df Residuals:                     317   BIC:                                      1112.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

plt.plot('d13c', 'd15n', data=df_jack4907,
         color='#018571', marker = 'o', markersize = 5, linewidth = 0)
plt.plot('d13c', 'd15n', data=df_sav,
         color='#a6611a', marker = 'o', markersize = 5, linewidth = 0)
plt.plot('d13c', 'd15n', data=df_stet,
         color='#e66101', marker = 'o', markersize = 5, linewidth = 0)
ax.set_ylabel(c)
ax.set_xlabel(n)
# Out:
# Text(0.5, 0, '$\\mathrm{\\delta}^{15}$N [‰]')

# %% [markdown]
# ## Chapter 1 Bulk figures

# %% [markdown]
# ### Focuses on recent $\mathrm{\delta}^{15}N$ changes at the base of the food web in the coastal Southeastern United States

# %% [markdown]
# # Fig. Stetson-4904 BC1 and Jacksonville-4684 BC1

# %%
mpl.rc('font',family='Helvetica')
# Query data points to highlight
new_df = df_jack4684.query('yrAD == 1922.0')

# Recent history, bulk d15N
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)

plt.plot('yrAD', 'd15n', data=df_stet,
         color='#D55E00',
         label = "Stetson-4904 BC1 (outer continental shelf)",
#          marker = ".", 
         markersize = 4)
plt.plot('yrAD', 'd15n', data=df_jack4684, 
         color='#5e3c99', 
         label = "Jacksonville-4684 BC1 (continental slope)",
#          marker = ".", 
         markersize = 4)
# plt.plot('yrAD', 'd15n', data=new_df, 
#          label = '_nolegend_',
#          color='yellow', marker = "o", markeredgecolor = "black", markersize = 4)

# Draw x label
ax.xaxis.set_label_position('top') # this moves the label to the top
ax.xaxis.set_ticks_position('top') # this moves the ticks to the top
ax.set_xlabel("Year CE", fontname = "Helvetica")

# Draw y label
ax.set_ylim(ax.get_ylim())
ax.set_ylabel(n, fontname = "Helvetica")

# Set limits
plt.xlim(1200, 2005)
plt.ylim(7, 11)

ax.xaxis.set_label_position('bottom') 
ax.xaxis.tick_bottom()
ax.tick_params(direction='in')
ax.xaxis.set_minor_locator(MultipleLocator(100))
ax.yaxis.set_minor_locator(MultipleLocator(0.25))
ax.tick_params(direction='in', which = 'both')

# Legend
plt.legend(frameon=False, loc=2)

#Set the font name for axis tick labels
for tick in ax.get_xticklabels():
    tick.set_fontname("Helvetica")
for tick in ax.get_yticklabels():
    tick.set_fontname("Helvetica")

# Save figure
plt.savefig('fig_stet_jack4684_d15n.png', dpi=300, bbox_inches='tight')

# %%
# Recent history, bulk d15N
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)

plt.plot('distance..mm.', 'd15n', data=df_jack4686,
         color='k',
         label = "Jacksonville-4686 BC1",
         marker = "o", 
         markersize = 4, alpha = 0.7)

# Draw x label
ax.xaxis.set_label_position('top') # this moves the label to the top
ax.xaxis.set_ticks_position('top') # this moves the ticks to the top
ax.set_xlabel("Distance from edge (mm)", fontname = "Helvetica")

# Draw y label
ax.set_ylim(ax.get_ylim())
ax.set_ylabel(n, fontname = "Helvetica")

ax.xaxis.set_label_position('bottom') 
ax.xaxis.tick_bottom()
ax.tick_params(direction='in')

# Legend
plt.legend(frameon=False)
plt.xticks(fontname = 'Helvetica')
plt.yticks(fontname = 'Helvetica')

# Set the font name for axis tick labels
# for tick in ax.get_xticklabels():
#     tick.set_fontname("Helvetica")
# for tick in ax.get_yticklabels():
#     tick.set_fontname("Helvetica")

# Save figure
plt.savefig('fig_jack4686_d15n.png', dpi=300, bbox_inches='tight')

# %%
# Recent history, bulk d13C
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)

plt.plot('distance..mm.', 'd13c', data=df_jack4686,
         color='k',
         label = "Jacksonville-4686 BC1",
         marker = "o", 
         markersize = 4, alpha = 0.7)

# Draw x label
ax.xaxis.set_label_position('top') # this moves the label to the top
ax.xaxis.set_ticks_position('top') # this moves the ticks to the top
ax.set_xlabel("Distance from edge (mm)", fontname = "Helvetica")

# Draw y label
ax.set_ylim(ax.get_ylim())
ax.set_ylabel(c, fontname = "Helvetica")

ax.xaxis.set_label_position('bottom') 
ax.xaxis.tick_bottom()
ax.tick_params(direction='in')

# Legend
plt.legend(frameon=False)
plt.xticks(fontname = 'Helvetica')
plt.yticks(fontname = 'Helvetica')

# Set the font name for axis tick labels
# for tick in ax.get_xticklabels():
#     tick.set_fontname("Helvetica")
# for tick in ax.get_yticklabels():
#     tick.set_fontname("Helvetica")

# Save figure
plt.savefig('fig_jack4686_d13c.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Paleoclimate comparison
# Since the d15N does not appear to be due to nutrient pollution (bc of timing and d15N-AA data), we can compare the records to known paleoclimatic records. A solid starting point would be known SST reconstructions in the Gulf of Mexico, Florida Straits and Gulf Stream region.
#
# Current roster of datasets:
#
# Richey, J. N., Poore, R. Z., Flower, B. P., & Quinn, T. M. (2007). 1400 yr multiproxy record of climate variability from the northern Gulf of Mexico. Geology, 35(5), 423–426. https://doi.org/10.1130/G23507A.1
#
# Richey, Julie N., Poore, R. Z., Flower, B. P., Quinn, T. M., & Hollander, D. J. (2009). Regionally coherent Little Ice Age cooling in the Atlantic Warm Pool. Geophysical Research Letters, 36(21). https://doi.org/10.1029/2009GL040445
#
# Saenger, C., Cohen, A. L., Oppo, D. W., Halley, R. B., & Carilli, J. E. (2009). Surface-temperature trends and variability in the low-latitude North Atlantic since 1552. Nature Geoscience, 2(7), 492–495. https://doi.org/10.1038/ngeo552
#
# Saenger, C., Came, R. E., Oppo, D. W., Keigwin, L. D., & Cohen, A. L. (2011). Regional climate variability in the western subtropical North Atlantic during the past two millennia. Paleoceanography, 26(2). https://doi.org/10.1029/2010PA002038

# %%
# load paleoclimate datasets
# R code
# Richey 2009; Gulf of Mexico
# fisk <- read.csv('~/Documents/GitHub/data/paleoclimate_data/richey2009-fisk.csv', header = TRUE)
# garrison <- read.csv('~/Documents/GitHub/data/paleoclimate_data/richey2009-garrison.csv', header = TRUE)

# Richey 2007; Gulf of Mexico
richey2007 = pd.read_csv('~/Documents/GitHub/data/paleoclimate_data/richey2007.csv')
richey2007.rename(columns={"Cal yr B.P.":"yrBP", "Core Depth (mm)":"depth (mm)", "% G. sacculifer":"percent gsacc"}, inplace = True)
richey2007["yrAD"] = 1950 - richey2007["yrBP"]

# Richey 2009; Gulf of Mexico
fisk = pd.read_csv('~/Documents/GitHub/data/paleoclimate_data/richey2009-fisk.csv')
fisk.rename(columns={"Core Depth (mm)":"depth (mm)"}, inplace = True)
fisk["yrAD"] = 1950 - fisk["yrBP"]

garrison = pd.read_csv('~/Documents/GitHub/data/paleoclimate_data/richey2009-garrison.csv')
garrison.rename(columns={"Core Depth (mm)":"depth (mm)"}, inplace = True)
garrison["yrAD"] = 1950 - garrison["yrBP"]

# Saenger 2009; Bahamas SST
saenger2009 = pd.read_csv('~/Documents/GitHub/data/paleoclimate_data/bahamas2009sst.csv')
saenger2009["yrBP"] = 1950 - saenger2009["yrAD"]

# Saenger 2011; Carolina slope
core1 = pd.read_csv('~/Documents/GitHub/data/paleoclimate_data/saenger2011_core1.csv')
core1.rename(columns={"Year(AD)":"yrAD"}, inplace = True)
core1["yrBP"] = 1950 - core1["yrAD"]

core2 = pd.read_csv('~/Documents/GitHub/data/paleoclimate_data/saenger2011_core2.csv')
core2.rename(columns={"Year(AD)":"yrAD"}, inplace = True)
core2["yrBP"] = 1950 - core2["yrAD"]

# Keigwin 1996; Bermuda rise
k4a = pd.read_table('~/Documents/GitHub/data/paleoclimate_data/bc004a-tab.txt', comment = "#", sep = '\t', header = 0)
k4a.rename(columns={"yrBP ":"yrBP"}, inplace = True)
k4a["yrAD"] = 1950 - k4a["yrBP"]

k4d = pd.read_table('~/Documents/GitHub/data/paleoclimate_data/bc004d-tab.txt', comment = "#", sep = '\t', header = 0)
k4d.rename(columns={"yrBP ":"yrBP"}, inplace = True)
k4d["yrAD"] = 1950 - k4d["yrBP"]

k4d_rub = k4d[k4d["carb%"] == -999]
k4d_carb = k4d[k4d["d18Og.rub"] == -999]

lundmc62 = pd.read_table('~/Documents/GitHub/data/paleoclimate_data/lund2006mc62.csv', comment = "#", sep = ',', header = 0)
lundmc62['yrAD'] = 1950 - lundmc62['CalAge1']

# print(richey2007)
# print(fisk)
# print(garrison)
# print(saenger2009)
# print(core1)
# print(core2)
# print(k4a)
# print(k4d)

# %%
core1
# Out:
#     yrAD  Mg/Ca   StdError(se)    up    dn  d18Oc    se  up.1  dn.1  \
# 0   1850    4.64          0.11  4.85  4.42  -1.46  0.10 -1.25 -1.66
# 1   1750    4.61          0.14  4.89  4.33  -1.53  0.10 -1.34 -1.73
# 2   1650    4.37          0.15  4.67  4.07  -1.52  0.10 -1.32 -1.73
# ..   ...     ...           ...   ...   ...    ...   ...   ...   ...
# 20   550    4.35          0.04  4.43  4.26  -1.42  0.05 -1.33 -1.52
# 21   500    4.37          0.04  4.45  4.28  -1.43  0.05 -1.34 -1.53
# 22   450    4.36          0.06  4.48  4.24  -1.44  0.06 -1.33 -1.55
#
#     SST(Anand)  ...   up.4   dn.4    SSS  se.2   up.5   dn.5  d18Ow  up.6  \
# 0        25.61  ...  25.96  25.57  36.42  0.11  36.53  36.31   1.24  1.27
# 1        25.55  ...  26.02  25.43  36.39  0.17  36.56  36.22   1.22  1.28
# 2        25.02  ...  25.97  25.07  36.33  0.15  36.48  36.18   1.20  1.25
# ..         ...  ...    ...    ...    ...   ...    ...    ...    ...   ...
# ...

# %%
k4d_carb
# Out:
#      depth    yrBP  carb%  d18Og.rub    yrAD
# 0      0.0     0.0  22.10     -999.0  1950.0
# 2      1.0    76.0  20.30     -999.0  1874.0
# 4      2.0   153.0  21.40     -999.0  1797.0
# ..     ...     ...    ...        ...     ...
# 97    49.0  3086.0  29.70     -999.0 -1136.0
# 99    50.0  3106.0  29.35     -999.0 -1156.0
# 101   51.0  3125.0  32.20     -999.0 -1175.0
#
# [51 rows x 5 columns]

# %% [markdown]
# ### Test plotting SST reconstructions from literature

# %%
# fig = plt.figure(figsize=(6,5))
# ax = fig.add_subplot(111)

# plt.plot('yrAD', 'SST', data=fisk, label = "Fisk", color = "k", linestyle = "--")
# plt.plot('yrAD', 'SST', data=garrison, label = "Garrison", color = "k", linestyle = "-")
# plt.plot('yrAD', 'SST', data=richey2007, label = "Richey (2007)", color = "k", linestyle = ":")


# # Draw x label
# ax.xaxis.set_label_position('top') # this moves the label to the top
# ax.xaxis.set_ticks_position('top') # this moves the ticks to the top
# ax.set_xlabel("Year CE")

# # Draw y label
# ax.set_ylim(ax.get_ylim())
# ax.set_ylabel(deg)

# # Set limits


# ax.xaxis.set_label_position('bottom') 
# ax.xaxis.tick_bottom()

# # Legend
# plt.legend(frameon=False)

# # Save figure
# plt.savefig('fig_sst_reconstructions_recent.png', dpi=300, bbox_inches='tight')

# %%
# fig = plt.figure(figsize=(6,5))
# ax = fig.add_subplot(111)

# plt.plot('yrAD', 'SST_anomaly', data=saenger2009, color = "k", linestyle = "-", label = "SST anomaly (Saenger 2009)")
# # plt.plot('yrAD', 'lower_se', data=saenger2009, color = "k", linestyle = "--")
# # plt.plot('yrAD', 'upper_se', data=saenger2009, color = "k", linestyle = "--")

# # Draw x label
# ax.xaxis.set_label_position('top') # this moves the label to the top
# ax.xaxis.set_ticks_position('top') # this moves the ticks to the top
# ax.set_xlabel("Year CE")

# # Draw y label
# ax.set_ylim(ax.get_ylim())
# ax.set_ylabel(deg)

# # Set limits


# ax.xaxis.set_label_position('bottom') 
# ax.xaxis.tick_bottom()

# # Legend
# plt.legend(frameon=False)

# # Save figure
# plt.savefig('fig_sst_reconstructions_bahamas.png', dpi=300, bbox_inches='tight')

# %%
# # Saenger 2011 cores

# fig = plt.figure()
# ax = fig.add_subplot(111)

# plt.plot('yrAD', 'SST(Anand)', data=core1, label="59GGC", color = 'k', linestyle="-")
# plt.plot('yrAD', "upper", data=core1, color = 'k', linestyle = ":")
# plt.plot('yrAD', "lower", data=core1, color = 'k', linestyle = ":")
# # plt.plot('yrAD', 'SST(Anand)', data=core2, label="MC22", color = 'k', linestyle = "--")

# ax.set_xlabel("Year CE")
# ax.set_ylabel(deg)

# plt.legend(frameon=False)

# %%
# core1["upper"] = core1["SST(Anand)"] + core1["sst_se"]
# core1["lower"] = core1["SST(Anand)"] - core1["sst_se"]

# fig, axs = plt.subplots(2, sharex = True, 
#                         gridspec_kw={'hspace': 0.05},
#                        figsize = (8,10))
# # fig.suptitle('Vertically stacked subplots')

# axs[0].plot('yrAD', 'SST', data=fisk, label = "Fisk", color = "k", linestyle = "--")
# axs[0].plot('yrAD', 'SST', data=garrison, label = "Garrison", color = "k", linestyle = "-")
# axs[0].plot('yrAD', 'SST', data=richey2007, label = "Richey (2007)", color = "k", linestyle = ":")

# axs[1].plot('yrAD', 'SST(Anand)', data=core1, label="59GGC", color = 'k', linestyle="-")
# axs[1].plot('yrAD', "upper", data=core1, color = 'k', linestyle = "--")
# axs[1].plot('yrAD', "lower", data=core1, color = 'k', linestyle = "--")


# # Draw x label
# axs[1].set_xlabel("Year CE")

# # Draw y label
# axs[0].set_ylabel(deg)
# axs[1].set_ylabel(deg)

# %%
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)

plt.plot('yrAD', 'SST', data=fisk, label = "Fisk", color = "k", linestyle = "--")
plt.plot('yrAD', 'SST', data=garrison, label = "Garrison", color = "k", linestyle = "-")
plt.plot('yrAD', 'SST', data=richey2007, label = "Richey (2007)", color = "k", linestyle = ":")


# Draw x label
ax.xaxis.set_label_position('top') # this moves the label to the top
ax.xaxis.set_ticks_position('top') # this moves the ticks to the top
ax.set_xlabel("Year CE")

# Draw y label
ax.set_ylim(ax.get_ylim())
ax.set_ylabel(deg)

# Set limits


ax.xaxis.set_label_position('bottom') 
ax.xaxis.tick_bottom()

# Legend
plt.legend(frameon=False)

# Save figure
plt.savefig('fig_sst_reconstructions_recent.png', dpi=300, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)

plt.plot('yrAD', 'carb%', data=k4a, label = "k4a", color = "k", linestyle = "--")
plt.plot('yrAD', 'carb%', data=k4d_carb, label = "k4d", color = "k", linestyle = "-")

# Draw x label
ax.xaxis.set_label_position('top') # this moves the label to the top
ax.xaxis.set_ticks_position('top') # this moves the ticks to the top
ax.set_xlabel("Year CE")

# Draw y label
ax.set_ylim(ax.get_ylim())
ax.set_ylabel("% Carbonate")

# Set limits
ax.xaxis.set_label_position('bottom') 
ax.xaxis.tick_bottom()

# Legend
plt.legend(frameon=False)

# Save figure
plt.savefig('fig_keigwin_1996.png', dpi=300, bbox_inches='tight')

# %%
fig, axs = plt.subplots(3, sharex = True, 
                        gridspec_kw={'hspace': 0.075},
                       figsize = (6,8))

axs[0].plot('yrAD', 'carb%', data=k4a, label = "k4a", color = "k", linestyle = "--", marker='o',markerfacecolor="white")
axs[0].plot('yrAD', 'carb%', data=k4d_carb, label = "k4d", color = "k", linestyle = "-",marker='o')

# axs[1].plot('yrAD', 'd15n', data=dataset, markerfacecolor = 'white', marker = 'o', color = 'k') # Binned data code from below
# axs[1].plot('yrAD', 'upper', data=dataset, color='k', linestyle = '--')
# axs[1].plot('yrAD', 'lower', data=dataset, color='k', linestyle = '--')

# axs[1].plot('yrAD', 'd15n', data=dataset0, color='k', marker = 'o')
# axs[1].plot('yrAD', 'upper', data=dataset0, color='k', linestyle = '--')
# axs[1].plot('yrAD', 'lower', data=dataset0, color='k', linestyle = '--')

# axs[1].plot('yrAD', 'd15n', data=dataset3, color='k', marker = "o", markerfacecolor='white')
# axs[1].plot('yrAD', 'upper', data=dataset3, color='r', marker = 'o')
# axs[1].plot('yrAD', 'lower', data=dataset3, color='r', marker = 'o')

axs[1].plot('yrAD', 'd13c', data=df_jack4907, 
         color='#018571', markeredgecolor = 'black', markersize = 8)
axs[1].plot('yrAD', 'd13c', data=df_stet, 
         color='blue', markeredgecolor = 'black', markersize = 8)


# axs[2].plot('yrAD', 'd18Og.rub', data=k4a, label = "k4a", color = "k", linestyle = "--", marker='o',markerfacecolor="white")
# axs[2].plot('yrAD', 'd18Og.rub', data=k4d_rub, label = "k4d", color = "k", linestyle = "-",marker='o')
axs[2].plot('yrAD', 'SST', data=richey2007, label = "Richey (2007)", color = "k", linestyle = ":")


axs[2].set_xlabel("Year CE")

axs[0].set_ylabel("% Carbonate")
axs[1].set_ylabel(n)

plt.savefig('fig_keigwin_comparison.png', dpi = 300, bbox_inches= 'tight')

# %% [markdown]
# # Figure. Stetson/Jacksonville d15N vs. SST reconstructions

# %%
lundmc62
# Out:
#     Depth  CalAge  Avg Mg/Ca  StdDev  StdErr  Sample    sst   yrAD
# 0    0.75    24.8       4.53    0.10    0.07       2  27.54   24.8
# 1    1.75    74.4       4.19    0.00    0.00       2  26.67   74.4
# 2    2.75   124.0       3.90    0.06    0.04       2  25.87  124.0
# ..    ...     ...        ...     ...     ...     ...    ...    ...
# 33  28.75   932.0       4.13    0.46    0.33       2  26.51  932.0
# 34  29.25   944.0       4.14    0.00    0.00       1  26.54  944.0
# 35  29.75   955.0       4.07    0.16    0.12       2  26.35  955.0
#
# [36 rows x 8 columns]

# %%
fig, axs = plt.subplots(4, sharex = True, 
                        gridspec_kw={'hspace': 0.075},
                       figsize = (6,12))
# fig.suptitle('Vertically stacked subplots')

axs[0].plot('yrAD', 'SST', data=fisk, label = "GOM Fisk (Richey et al, 2009)", color = "k", linestyle = "--")
axs[0].plot('yrAD', 'SST', data=garrison, label = "GOM Garrison (Richey et al, 2009)", color = "k", linestyle = "-.")
axs[0].plot('yrAD', 'SST', data=richey2007, label = "GOM (Richey et al, 2007)", color = "k", linestyle = "-")

axs[2].plot('yrAD', 'd15n', data=df_stet, label="Stetson black coral (fresh POM proxy)", color = '#e66101', linestyle="-")
axs[2].plot('yrAD', 'd15n', data=df_jack4684, label="Jacksonville black coral (fresh POM proxy)", color = '#5e3c99', linestyle="-")

axs[3].plot('yrAD', 'Mg/Ca', data=lundmc62, color = 'k', linestyle="-", label = 'Lund')

# axs[2].plot('yrAD', 'd13c', data=df_stet, label="Stetson-4904 BC1", color = '#e66101', linestyle="-")

axs[1].plot('yrAD', 'SST_anomaly', data=saenger2009, color = "k", linestyle = "-", label = "Bahamas SST anomaly (Saenger et al, 2009)")

# Set limits
axs[2].set_xlim(100, 2005)
axs[2].set_ylim(7, 10.25)

# Draw x label
axs[3].set_xlabel("Year CE")

# Legend
axs[0].legend(frameon=False)
axs[1].legend(frameon=False)
axs[2].legend(frameon=False)
axs[3].legend(frameon=False)

# Draw y label
axs[0].set_ylabel(deg)
axs[1].set_ylabel(deg)
# axs[2].set_ylabel(c)
axs[2].set_ylabel(n)

# Save figure
# plt.savefig('fig_sst_reconstructions_recent.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0, 0.5, '$\\mathrm{\\delta}^{15}$N [‰]')

# %% [markdown]
# ## d15N-AA data through time

# %%
myfile = '~/Documents/GitHub/data/cleaned_ndata_12-22-2019.csv'
ndata = pd.read_csv(myfile, sep=',') # Contains SEUS black coral data, GOM black corals, and some POM data from elsewhere

# %%
ndata
# Out:
#           Sample ID           Sample ID2                Type  \
# 0    sav-4902-bc1_2  Savannah Banks-4902  Black Coral - SEUS
# 1    sav-4902-bc1_7  Savannah Banks-4902  Black Coral - SEUS
# 2   sav-4902-bc1_15  Savannah Banks-4902  Black Coral - SEUS
# ..              ...                  ...                 ...
# 42       E 500-1000                  POM          POM - E NA
# 43      E 1000-2000                  POM          POM - E NA
# 44          E >2000                  POM          POM - E NA
#
#                     Region  Bulk    Glu    Asp    Ala    Ile    Leu  ...  Lys  \
# 0                     SEUS  8.95  14.26  13.56  16.14  20.67  19.28  ...  NaN
# 1                     SEUS  9.02  14.16  18.95  20.76  24.40  23.31  ...  NaN
# 2                     SEUS  9.97  17.29  14.35  18.60  23.82  22.69  ...  NaN
# ..                     ...   ...    ...    ...    ...    ...    ...  ...  ...
# 42  Eastern North Atlantic  3.80  12.70  10.00  13.70   8.80   9.20  ...  2.2
# ...

# %%
filter1 = ndata[(ndata['Region'] == 'SEUS') | (ndata['Region'] == 'Gulf of Mexico')]
filter2 = ndata[(ndata['Region'] == 'SEUS')]
seus = ndata[(ndata['Region'] == 'SEUS')]
gom = ndata[(ndata['Region'] == 'Gulf of Mexico')]
# ndata = filter1
# ndata

# %%
# Subset the data
# NOTE: It is possible to write a for loop to do this, but I am doing this to save time
# https://stackoverflow.com/questions/21654635/scatter-plots-in-pandas-pyplot-how-to-plot-by-category

n_jack = ndata[ndata['Sample ID2']=='Jacksonville-4907']
n_jack2 = ndata[ndata['Sample ID2']=='Jacksonville-4684']
n_sav = ndata[ndata['Sample ID2']=='Savannah Banks-4902']
markersize = 10

fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)
ax.set_xlabel("Year CE")
# ax.set_ylabel(r'Phe $\mathrm{\delta}^{15}$N ['u"\u2030]")
ax.set_ylabel('Trophic Position')

# plt.plot('Year CE', 'Phe', data = n_jack, label = "Jacksonville-4907", marker = "D", linestyle = "--", color = "#2c7fb8", markeredgecolor = "k", markersize = markersize)
# plt.plot('Year CE', 'Phe', data = n_jack2, label = "Jacksonville-4684", marker = "s", linestyle = "--", color = "#41b6c4", markeredgecolor = "k", markersize = markersize)
# plt.plot('Year CE', 'Phe', data = n_sav, label = "Savannah-4902", marker = "^", linestyle = "--", color = "#a1dab4", markeredgecolor = "k", markersize = markersize)
plt.plot('Year CE', 'TP', data = seus, label = "SEUS", marker = "^", color = "gray", linestyle = "None", markeredgecolor = "k", markersize = markersize)
plt.plot('Year CE', 'TP', data = gom, label = "GOM", marker = "o", color = "lightgray", linestyle = "None", markeredgecolor = "k", markersize = markersize)

ax.tick_params(direction='in')
               
# Legend
plt.legend(frameon=False)

# Save figure
plt.savefig('fig_TrophicPosition_time.png', dpi=300, bbox_inches='tight')

# %%
# Trophic position

fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)
ax.set_xlabel("Year CE")
ax.set_ylabel('Trophic Position [Glu-Phe]')

plt.plot('Year CE', 'TP', data = n_jack, label = "Jacksonville-4907", marker = "D", linestyle = "--", color = "#2c7fb8", markeredgecolor = "k", markersize = markersize)
plt.plot('Year CE', 'TP', data = n_jack2, label = "Jacksonville-4684", marker = "s", linestyle = "--", color = "#41b6c4", markeredgecolor = "k", markersize = markersize)
plt.plot('Year CE', 'TP', data = n_sav, label = "Savannah-4902", marker = "^", linestyle = "--", color = "#a1dab4", markeredgecolor = "k", markersize = markersize)

ax.tick_params(direction='in')

# Legend
plt.legend(frameon=False, loc = 2)

# Save figure
plt.savefig('fig_trophicposition_time.png', dpi=300, bbox_inches='tight')

# %%
# Sum V

fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)
ax.set_xlabel("Year CE")
ax.set_ylabel('Sum V [permil]')

plt.plot('Year CE', 'Sum V', data = n_jack, label = "Jacksonville-4907", marker = "D", linestyle = "--", color = "#2c7fb8", markeredgecolor = "k", markersize = markersize)
plt.plot('Year CE', 'Sum V', data = n_jack2, label = "Jacksonville-4684", marker = "s", linestyle = "--", color = "#41b6c4", markeredgecolor = "k", markersize = markersize)
plt.plot('Year CE', 'Sum V', data = n_sav, label = "Savannah-4902", marker = "^", linestyle = "--", color = "#a1dab4", markeredgecolor = "k", markersize = markersize)

ax.tick_params(direction='in')

# Legend
plt.legend(frameon=False, loc = 0)

# Save figure
plt.savefig('fig_sum-v_time.png', dpi=300, bbox_inches='tight')

# %%
# low-resolution bulk vs phe

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("Year CE")
ax.set_ylabel(r'$\mathrm{\delta}^{15}$N ['u"\u2030]")

plt.plot('Year CE', 'Bulk', data = n_jack2, label = "Bulk", marker = "D", linestyle = "--", linewidth=1, color = 'k', markerfacecolor = "#2c7fb8", markeredgecolor = "k", markersize = markersize)
plt.plot('Year CE', 'Phe', data = n_jack2, label = "Phe", marker = "s", linestyle = "--", linewidth = 1, color = 'k', markerfacecolor = "#41b6c4", markeredgecolor = "k", markersize = markersize)

plt.legend(frameon=False, loc = 3)
plt.savefig("fig_bulk_phe_recent.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Multiple plots in one figure

# %% [markdown]
# ### Jacksonville-4684 BC1 d15N-AA parameters

# %%
fig, axs = plt.subplots(3, sharex = True, figsize = (6,9))
fig.suptitle("Jacksonville-4684 BC1")

axs[0].plot('Year CE', 'TP', data = n_jack2, label = "Jacksonville-4684", marker = "s", linestyle = "--", linewidth = 1, color = 'k', markerfacecolor = "#1b9e77", markeredgecolor = "k", markersize = markersize)
axs[1].plot('Year CE', 'Bulk', data = n_jack2, label = "Jacksonville-4684", marker = ">", linestyle = "--", linewidth = 1, color = 'k', markerfacecolor = "#d95f02", markeredgecolor = "k", markersize = markersize)
axs[2].plot('Year CE', 'Phe', data = n_jack2, label = "Jacksonville-4684", marker = "<", linestyle = "--", linewidth = 1, color = 'k', markerfacecolor = "#7570b3", markeredgecolor = "k", markersize = markersize)

# axs[0].legend(frameon=False)
# axs[1].legend(frameon=False)

axs[2].set_xlabel("Year CE")
axs[2].set_ylabel(r'Phe $\mathrm{\delta}^{15}$N ['u"\u2030]")
axs[1].set_ylabel(r'Bulk $\mathrm{\delta}^{15}$N ['u"\u2030]")
axs[0].set_ylabel('TP [Glu-Phe]')

plt.savefig('fig_jack4684_d15nAA_time_2.png', dpi = 300, bbox_inches = 'tight')

# %% [markdown]
# ## Figure. Bulk d15N with TP and Phe figures on top

# %%
fig, axs = plt.subplots(3, sharex = True, figsize = (5,8))

axs[0].plot('Year CE', 'TP', data = n_jack2, label = "Jacksonville-4684", marker = "s", linestyle = "--", linewidth = 1, color = 'k', markerfacecolor = "#1b9e77", markeredgecolor = "k", markersize = markersize)
axs[1].plot('Year CE', 'Phe', data = n_jack2, label = "Jacksonville-4684", marker = "<", linestyle = "--", linewidth = 1, color = 'k', markerfacecolor = "#7570b3", markeredgecolor = "k", markersize = markersize)
axs[2].plot('yrAD', 'd15n', data = df_jack4684, label = "Jacksonville-4684", marker = ">", linestyle = "--", linewidth = 1, color = 'k', markerfacecolor = "#d95f02", markeredgecolor = "k", markersize = markersize)

axs[2].set_xlabel("Year CE")
axs[1].set_ylabel(r'Phe $\mathrm{\delta}^{15}$N ['u"\u2030]")
axs[2].set_ylabel(r'Bulk $\mathrm{\delta}^{15}$N ['u"\u2030]")
axs[0].set_ylabel('TP [Glu-Phe]')

axs[2].set_xlim(1500,2005)
# Out:
# (1500, 2005)

# %% [markdown]
# ### d15N-AA parameters (Phe and TP through time with all corals)

# %%
fig, axs = plt.subplots(2, sharex = True, figsize = (6,8),
                       gridspec_kw={'hspace': 0.075})

# Phe
axs[0].plot('Year CE', 'Phe', data = n_jack, label = "Jacksonville-4907", marker = "D", linestyle = "--", color = "#2c7fb8", markeredgecolor = "k", markersize = markersize)
axs[0].plot('Year CE', 'Phe', data = n_jack2, label = "Jacksonville-4684", marker = "s", linestyle = "--", color = "#41b6c4", markeredgecolor = "k", markersize = markersize)
axs[0].plot('Year CE', 'Phe', data = n_sav, label = "Savannah-4902", marker = "^", linestyle = "--", color = "#a1dab4", markeredgecolor = "k", markersize = markersize)

# Trophic position
axs[1].plot('Year CE', 'TP', data = n_jack, label = "Jacksonville-4907", marker = "D", linestyle = "--", color = "#2c7fb8", markeredgecolor = "k", markersize = markersize)
axs[1].plot('Year CE', 'TP', data = n_jack2, label = "Jacksonville-4684", marker = "s", linestyle = "--", color = "#41b6c4", markeredgecolor = "k", markersize = markersize)
axs[1].plot('Year CE', 'TP', data = n_sav, label = "Savannah-4902", marker = "^", linestyle = "--", color = "#a1dab4", markeredgecolor = "k", markersize = markersize)

# Legend
axs[0].legend(frameon=False, loc = 0)
axs[1].legend(frameon=False, loc = 0)

axs[1].set_xlabel("Year CE")
axs[0].set_ylabel(r'Phe $\mathrm{\delta}^{15}$N ['u"\u2030]")
axs[1].set_ylabel('TP [Glu-Phe]')

plt.savefig('fig_phe_tp_through_time_2.png', dpi = 300, bbox_inches='tight')

# %% [markdown]
# ## Smoothing time series data (Test code)
# https://stackoverflow.com/questions/6163334/binning-data-in-python-with-scipy-numpy # Didn't seem to work
# https://dfrieds.com/data-analysis/bin-values-python-pandas
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html
#
# Note: try code from Pyleoclim package

# %%
# Using a binning function from Python package Pyleoclim

import numpy as np
import pandas as pd
import warnings
import copy
from scipy import special
import sys
from scipy import signal

def binvalues(x, y, bin_size=None, start=None, end=None):
    """ Bin the values
    Args:
        x (array): the x-axis series.
        y (array): the y-axis series.
        bin_size (float): The size of the bins. Default is the average resolution
        start (float): Where/when to start binning. Default is the minimum
        end (float): When/where to stop binning. Defulat is the maximum
    Returns:
        binned_values - the binned output \n
        bins - the bins (centered on the median, i.e., the 100-200 bin is 150) \n
        n - number of data points in each bin \n
        error -  the standard error on the mean in each bin
    """

    # Make sure x and y are numpy arrays
    x = np.array(x, dtype='float64')
    y = np.array(y, dtype='float64')

    # Get the bin_size if not available
    if bin_size is None:
        bin_size = np.nanmean(np.diff(x))

    # Get the start/end if not given
    if start is None:
        start = np.nanmin(x)
    if end is None:
        end = np.nanmax(x)

    # Set the bin medians
    bins = np.arange(start+bin_size/2, end + bin_size/2, bin_size)

    # Perform the calculation
    binned_values = []
    n = []
    error = []
    for val in np.nditer(bins):
        idx = [idx for idx, c in enumerate(x) if c >= (val-bin_size/2) and c < (val+bin_size/2)]
        if y[idx].size == 0:
            binned_values.append(np.nan)
            n.append(np.nan)
            error.append(np.nan)
        else:
            binned_values.append(np.nanmean(y[idx]))
            n.append(y[idx].size)
            error.append(np.nanstd(y[idx]))

    return bins, binned_values, n, error

# %%
x=df_jack4907["yrAD"]
y=df_jack4907["d15n"]
newdf = binvalues(x,y, bin_size = 80)
newdf = np.asarray(newdf)

newdf = np.transpose(newdf)
newdf.shape

data=newdf
dataset0 = pd.DataFrame({'yrAD': data[:, 0], 'd15n': data[:, 1], 'Column3': data[:, 2], 'Column4': data[:, 3]})
dataset0['upper'] = dataset0['d15n'] + dataset0['Column4']
dataset0['lower'] = dataset0['d15n'] - dataset0['Column4']

dataset0
# Out:
#       yrAD      d15n  Column3   Column4     upper     lower
# 0  -1103.0  7.968947     19.0  0.526017  8.494964  7.442931
# 1  -1023.0  7.582222     18.0  0.441142  8.023364  7.141080
# 2   -943.0  7.841053     19.0  0.323905  8.164958  7.517147
# ..     ...       ...      ...       ...       ...       ...
# 27  1057.0  9.230000      4.0  0.420416  9.650416  8.809584
# 28  1137.0  8.830000      3.0  0.414085  9.244085  8.415915
# 29  1217.0  9.605000      2.0  0.175000  9.780000  9.430000
#
# [30 rows x 6 columns]

# %%
plt.plot(x,y, 'b.', label='raw data')
plt.plot('yrAD', 'd15n', data=dataset0, color='g')
plt.plot('yrAD', 'upper', data=dataset0, color='r', marker = 'o')
plt.plot('yrAD', 'lower', data=dataset0, color='r', marker = 'o')

# %%
# Binning the Stetson-4904 BC1 data
newdf = binvalues(df_stet['yrAD'],df_stet['d15n'], bin_size = 100)
newdf = np.asarray(newdf)

newdf = np.transpose(newdf)
newdf.shape
data=newdf
dataset = pd.DataFrame({'yrAD': data[:, 0], 'd15n': data[:, 1], 'Column3': data[:, 2], 'Column4': data[:, 3]})

dataset['upper'] = dataset['d15n'] + dataset['Column4']
dataset['lower'] = dataset['d15n'] - dataset['Column4']

plt.plot(df_stet['yrAD'],df_stet['d15n'], 'b.', label='raw data')
plt.plot('yrAD', 'd15n', data=dataset, color='g', marker = 'o')
plt.plot('yrAD', 'upper', data=dataset, color='r', marker = 'o')
plt.plot('yrAD', 'lower', data=dataset, color='r', marker = 'o')

# %%
dataset
# Out:
#       yrAD      d15n  Column3   Column4
# 0    498.0  7.327708     29.0  0.579516
# 1    598.0  7.890323     31.0  0.788492
# 2    698.0  7.574687     32.0  0.353536
# ..     ...       ...      ...       ...
# 13  1798.0  8.371200     25.0  0.434109
# 14  1898.0  8.564815     27.0  0.387694
# 15  1998.0  9.273529     17.0  0.333748
#
# [16 rows x 4 columns]

# %%
2015-1920
# Out:
# 95

# %%
# Binning the Jacksonville-4684 BC1 data
newdf = binvalues(df_jack4684['yrAD'],df_jack4684['d15n'], bin_size = 20)
newdf = np.asarray(newdf)

newdf = np.transpose(newdf)
newdf.shape
data=newdf
dataset2 = pd.DataFrame({'yrAD': data[:, 0], 'd15n': data[:, 1], 'Column3': data[:, 2], 'Column4': data[:, 3]})

dataset2['upper'] = dataset2['d15n'] + dataset2['Column4']
dataset2['lower'] = dataset2['d15n'] - dataset2['Column4']

plt.plot(df_jack4684['yrAD'],df_jack4684['d15n'], 'b.', label='raw data')
plt.plot('yrAD', 'd15n', data=dataset2, color='g')
plt.plot('yrAD', 'upper', data=dataset2, color='r', marker = 'o')
plt.plot('yrAD', 'lower', data=dataset2, color='r', marker = 'o')

# %%
dataset2
# Out:
#       yrAD      d15n  Column3   Column4
# 0   1703.0  8.174286      7.0  0.188290
# 1   1723.0  8.057500      8.0  0.237316
# 2   1743.0  7.973750      8.0  0.296730
# ..     ...       ...      ...       ...
# 9   1883.0  8.474000      5.0  0.450537
# 10  1903.0  8.448750      8.0  0.422387
# 11  1923.0  9.063333      6.0  0.499555
#
# [12 rows x 4 columns]

# %%
# Binning the Savannah-4902 BC1 data

newdf = binvalues(df_sav['yrAD'],df_sav['d15n'], bin_size = 50)
newdf = np.asarray(newdf)

newdf = np.transpose(newdf)
newdf.shape
data=newdf
dataset3 = pd.DataFrame({'yrAD': data[:, 0], 'd15n': data[:, 1], 'Column3': data[:, 2], 'Column4': data[:, 3]})
dataset3['upper'] = dataset3['d15n'] + dataset3['Column4']
dataset3['lower'] = dataset3['d15n'] - dataset3['Column4']

# plt.plot(df_sav['yrAD'],df_sav['d15n'], 'b.', label='raw data')
plt.plot('yrAD', 'd15n', data=dataset3, color='g')
plt.plot('yrAD', 'upper', data=dataset3, color='r', marker = 'o')
plt.plot('yrAD', 'lower', data=dataset3, color='r', marker = 'o')

# plt.plot(x,y, 'b.', label='raw data')
# plt.plot('yrAD', 'd15n', data=dataset0, color='r')

# plt.plot('yrAD', 'd15n', data=dataset2, color='b')

plt.plot('yrAD', 'd15n', data=dataset, color='purple')

# %%
dataset3
# Out:
#       yrAD       d15n  Column3   Column4
# 0   -217.0   7.952000      5.0  0.380021
# 1   -167.0   8.935000      4.0  0.253427
# 2   -117.0   9.013333      3.0  0.237954
# ..     ...        ...      ...       ...
# 29  1233.0  10.080000      2.0  0.370000
# 30  1283.0   9.242000      5.0  0.280100
# 31  1333.0   8.690000      4.0  0.407615
#
# [32 rows x 4 columns]

# %%
1333-1283
# Out:
# 50

# %%
plt.scatter('Sum V', 'TP', data=ndata, color='k', marker = 'o')

# %%
ndata
# Out:
#           Sample ID           Sample ID2                Type  \
# 0    sav-4902-bc1_2  Savannah Banks-4902  Black Coral - SEUS
# 1    sav-4902-bc1_7  Savannah Banks-4902  Black Coral - SEUS
# 2   sav-4902-bc1_15  Savannah Banks-4902  Black Coral - SEUS
# ..              ...                  ...                 ...
# 42       E 500-1000                  POM          POM - E NA
# 43      E 1000-2000                  POM          POM - E NA
# 44          E >2000                  POM          POM - E NA
#
#                     Region  Bulk    Glu    Asp    Ala    Ile    Leu  ...  \
# 0                     SEUS  8.95  14.26  13.56  16.14  20.67  19.28  ...
# 1                     SEUS  9.02  14.16  18.95  20.76  24.40  23.31  ...
# 2                     SEUS  9.97  17.29  14.35  18.60  23.82  22.69  ...
# ..                     ...   ...    ...    ...    ...    ...    ...  ...
# 42  Eastern North Atlantic  3.80  12.70  10.00  13.70   8.80   9.20  ...
# ...
