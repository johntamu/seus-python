# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
# Import data
df = pd.read_csv('~/Documents/GitHub/data/schiff c-csiaa data from schiff_larsen_in prog.csv')
df = df[['Group ID','Group ID2','Feature', 'Ala', 'Asx', 'Glx', 'Gly', 'Ser', 'Pro', 'Ile', 'Leu', 'Lys', 'Phe', 'Thr', 'Tyr', 'Val']]
df
# Out:
#                     Group ID   Group ID2                 Feature   Ala   Asx  \
# 0                         B1    Bacteria                Bacteria -11.3 -12.9
# 1                         B2    Bacteria                     NaN -12.2 -17.6
# 2                         B3    Bacteria                     NaN -15.9 -21.8
# 3                         B4    Bacteria                Bacteria -22.6 -22.7
# 4                         B5    Bacteria                     NaN -14.8 -17.4
# ..                       ...         ...                     ...   ...   ...
# 163          Prochlorococcus  Prokaryote           Non-N2 fixing  -5.5  -0.5
# 164             Rhodococcous  Prokaryote  Heterotrophic bacteria -28.3 -24.7
# 165           Actinobacteria  Prokaryote  Heterotrophic bacteria -28.6 -24.9
# 166  Burkholderia xenovorans  Prokaryote  Heterotrophic bacteria -12.5 -12.8
# 167         Escherichia coli  Prokaryote  Heterotrophic bacteria -11.2 -14.9
#
#       Glx   Gly   Ser   Pro   Ile   Leu   Lys   Phe   Thr   Tyr   Val
# 0   -11.5 -12.9   NaN   NaN -12.0 -12.8 -10.4 -18.8  -5.2 -16.8 -13.6
# 1   -17.8 -13.9   NaN   NaN -12.9 -13.0 -14.9 -17.0  -8.2 -18.1 -14.1
# 2   -18.3 -21.3   NaN   NaN -18.9 -19.9 -20.3 -24.6 -15.0 -22.9 -20.8
# 3   -22.9 -25.3   NaN   NaN -23.7 -25.2 -21.2 -28.9 -15.1 -27.7 -26.4
# 4   -16.5 -13.8   NaN   NaN -16.1 -17.7 -14.8 -18.3  -8.3 -18.0 -17.8
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 163 -13.8 -41.6  -6.8 -12.4 -12.8 -21.5   NaN -22.1  -9.5   NaN -17.6
# 164 -25.9 -37.3 -19.3 -20.0 -27.3 -26.2 -23.8 -29.2 -18.4   NaN -26.8
# 165 -25.3 -38.0 -19.2 -20.2 -28.0 -26.5 -22.3 -29.5 -18.2   NaN -27.8
# 166 -14.5 -12.2   1.2  -8.5 -14.2 -12.9 -10.1 -19.0 -10.1   NaN -16.0
# 167 -15.6  -9.7  -4.2 -14.3 -12.5 -14.0 -11.5 -15.5 -11.5   NaN -13.6
#
# [168 rows x 16 columns]

# %%
# Isolate EAA
df = df[['Group ID','Feature', 'Phe', 'Thr', 'Ile', 'Leu', 'Val']]
df
# Out:
#                     Group ID                 Feature   Phe   Thr   Ile   Leu  \
# 0                         B1                Bacteria -18.8  -5.2 -12.0 -12.8
# 1                         B2                     NaN -17.0  -8.2 -12.9 -13.0
# 2                         B3                     NaN -24.6 -15.0 -18.9 -19.9
# 3                         B4                Bacteria -28.9 -15.1 -23.7 -25.2
# 4                         B5                     NaN -18.3  -8.3 -16.1 -17.7
# ..                       ...                     ...   ...   ...   ...   ...
# 163          Prochlorococcus           Non-N2 fixing -22.1  -9.5 -12.8 -21.5
# 164             Rhodococcous  Heterotrophic bacteria -29.2 -18.4 -27.3 -26.2
# 165           Actinobacteria  Heterotrophic bacteria -29.5 -18.2 -28.0 -26.5
# 166  Burkholderia xenovorans  Heterotrophic bacteria -19.0 -10.1 -14.2 -12.9
# 167         Escherichia coli  Heterotrophic bacteria -15.5 -11.5 -12.5 -14.0
#
#       Val
# 0   -13.6
# 1   -14.1
# 2   -20.8
# 3   -26.4
# 4   -17.8
# ..    ...
# 163 -17.6
# 164 -26.8
# 165 -27.8
# 166 -16.0
# 167 -13.6
#
# [168 rows x 7 columns]

# %%
# Split into two datasets
df_train = df[(df['Feature'] == 'Cyanobacteria') | (df['Feature'] == 'Macroalgae') 
              | (df['Feature'] == 'Microalgae')]
df_train = df_train[['Group ID','Feature', 'Phe', 'Thr', 'Ile', 'Leu', 'Val']]
df_train = df_train.dropna()

df_test = df[(df['Feature'] == 'Leiopathes-post') | (df['Feature'] == 'Leiopathes-pre')]

# %%
df_train
# Out:
#                     Group ID        Feature   Phe   Thr   Ile   Leu   Val
# 34                        R1     Macroalgae -19.2  -6.4 -17.3 -20.2 -19.2
# 35                        R2     Macroalgae -20.7  -4.8 -15.4 -19.5 -21.3
# 36                        R3     Macroalgae -25.3  -9.2 -21.7 -25.8 -25.4
# 37                        R4     Macroalgae -23.7 -11.0 -17.0 -21.9 -19.8
# 38                        R5     Macroalgae -25.3 -15.3 -19.5 -22.5 -22.4
# 39                        R6     Macroalgae -21.1  -8.7 -16.5 -21.0 -20.7
# 40                        R7     Macroalgae -21.1  -5.9 -16.7 -21.0 -20.3
# 41                        R8     Macroalgae -22.0  -7.3 -18.0 -23.5 -23.6
# 42                        R9     Macroalgae -22.5  -6.8 -20.4 -23.4 -20.9
# 43                        P1     Macroalgae -19.4  -3.6 -17.6 -23.1 -18.8
# 44                        P2     Macroalgae -19.1  -1.2 -15.2 -21.5 -17.0
# 45                        P3     Macroalgae -22.2  -5.5 -19.6 -24.8 -20.7
# 46                        P4     Macroalgae -18.9  -0.4 -16.8 -20.0 -15.7
# 47                        P5     Macroalgae -23.9  -6.4 -21.4 -26.1 -22.5
# 48                        P6     Macroalgae -12.8  -2.6  -6.3 -13.3 -10.4
# 49                        P7     Macroalgae -18.8  -1.2 -15.6 -23.9 -19.1
# 50                        P8     Macroalgae -20.4  -0.5 -19.5 -25.5 -19.6
# 51                        P9     Macroalgae -16.7   0.9 -10.9 -18.3 -14.5
# 52                       P10     Macroalgae -23.6   5.4 -16.9 -23.6 -21.2
# 53                       P11     Macroalgae -12.7   0.8  -7.3 -14.7 -10.9
# 54                       P12     Macroalgae -21.2  -8.6 -17.6 -25.2 -22.4
# 57                        C3  Cyanobacteria -19.8  -5.9 -17.3 -23.3 -20.5
# 58                        C4  Cyanobacteria -24.0 -10.1 -20.0 -25.8 -24.2
# 61                        D3     Microalgae -20.6  -7.0 -16.5 -22.1 -19.7
# 62                        D4     Microalgae -23.8 -10.8 -16.1 -25.5 -22.9
# 63                        D5     Microalgae -16.0  -4.6 -10.4 -19.3 -15.5
# 64                        H1     Microalgae -23.2  -9.1 -18.3 -27.2 -24.9
# 65                        H2     Microalgae -24.6  -8.6 -19.2 -23.8 -21.1
# 66                        H3     Microalgae -25.0  -8.9 -18.3 -31.4 -26.8
# 67                        H4     Microalgae -21.6  -6.8 -13.8 -20.5 -18.8
# 68                        K1     Microalgae -19.7  -6.7 -15.8 -23.7 -19.2
# 69                        K2     Microalgae -21.4  -2.2 -15.3 -23.3 -20.6
# 70                        K3     Microalgae -15.9  -8.1 -10.4 -15.7 -13.0
# 71                        K4     Microalgae -15.7  -4.2 -11.4 -16.7 -15.3
# 72                        K5     Microalgae -22.2  -6.4 -16.3 -23.2 -20.4
# 73                        K6     Microalgae -18.4  -7.1 -11.4 -18.4 -15.9
# 154         Cyanothece (NO3)  Cyanobacteria -26.6 -32.6 -38.5 -36.9 -37.4
# 155          Cyanothece (N2)  Cyanobacteria -38.7 -30.7 -39.3 -43.7 -38.5
# 161  Trichodesmium culture 1  Cyanobacteria -14.9  -9.4 -23.1 -23.1 -20.6
# 162  Trichodesmium culture 2  Cyanobacteria -15.0 -16.3 -22.2 -19.1 -23.7

# %%
df_test
# Out:
#           Group ID          Feature        Phe       Thr        Ile  \
# 131    STET-4904 7  Leiopathes-post -19.623750 -7.448889 -12.163636
# 132    STET-4904 8  Leiopathes-post -21.996354 -1.860000 -16.820061
# 133   STET-4904 22  Leiopathes-post -19.587812 -4.630303 -12.309727
# 134   STET-4904 25  Leiopathes-post -22.747031 -5.781667  -9.529455
# 135   STET-4904 40   Leiopathes-pre -21.797734 -0.220303 -15.017182
# 136   STET-4904 46   Leiopathes-pre -20.357031  1.686869 -12.158030
# 137  STET-4904 103   Leiopathes-pre -21.560859 -4.580303 -12.473273
# 138  STET-4904 109   Leiopathes-pre -19.111016 -4.384091 -12.110909
# 139  STET-4904 135   Leiopathes-pre -22.362500 -5.630303 -14.977455
# 140  STET-4904 170   Leiopathes-pre -21.988047 -0.651768  -8.972879
#
#            Leu        Val
# 131 -25.172121 -15.392533
# 132 -24.690121 -16.709400
# 133 -24.130273 -15.469500
# 134 -22.147182 -16.270700
# 135 -21.781455 -15.897200
# 136 -26.378636 -16.711833
# 137 -22.838000 -20.469200
# 138 -20.853273 -16.111000
# 139 -24.698545 -16.792400
# 140 -25.730152 -16.371833

# %%
df_pca = pd.concat([df_train, df_test], axis=0)
df_pca = df_pca.reset_index()

groups = ['C3','C4', 'Cyanothece (NO3)', 'Cyanothece (N2)']
df_pca = df_pca[~df_pca['Group ID'].isin(groups)] # Drop unwanted groups

df_pca = df_pca.reset_index()
df_pca
# Out:
#     level_0  index                 Group ID          Feature        Phe  \
# 0         0     34                       R1       Macroalgae -19.200000
# 1         1     35                       R2       Macroalgae -20.700000
# 2         2     36                       R3       Macroalgae -25.300000
# 3         3     37                       R4       Macroalgae -23.700000
# 4         4     38                       R5       Macroalgae -25.300000
# 5         5     39                       R6       Macroalgae -21.100000
# 6         6     40                       R7       Macroalgae -21.100000
# 7         7     41                       R8       Macroalgae -22.000000
# 8         8     42                       R9       Macroalgae -22.500000
# 9         9     43                       P1       Macroalgae -19.400000
# 22 -10.800000 -16.100000 -25.500000 -22.900000
# 23  -4.600000 -10.400000 -19.300000 -15.500000
# 24  -9.100000 -18.300000 -27.200000 -24.900000
# 25  -8.600000 -19.200000 -23.800000 -21.100000
# 26  -8.900000 -18.300000 -31.400000 -26.800000
# 27  -6.800000 -13.800000 -20.500000 -18.800000
# 28  -6.700000 -15.800000 -23.700000 -19.200000
# 29  -2.200000 -15.300000 -23.300000 -20.600000
# 30  -8.100000 -10.400000 -15.700000 -13.000000
# 31  -4.200000 -11.400000 -16.700000 -15.300000
# 32  -6.400000 -16.300000 -23.200000 -20.400000
# 33  -7.100000 -11.400000 -18.400000 -15.900000
# 34  -9.400000 -23.100000 -23.100000 -20.600000
# 35 -16.300000 -22.200000 -19.100000 -23.700000
# 36  -7.448889 -12.163636 -25.172121 -15.392533
# 37  -1.860000 -16.820061 -24.690121 -16.709400
# 38  -4.630303 -12.309727 -24.130273 -15.469500
# 39  -5.781667  -9.529455 -22.147182 -16.270700
# 40  -0.220303 -15.017182 -21.781455 -15.897200
# 41   1.686869 -12.158030 -26.378636 -16.711833
# 42  -4.580303 -12.473273 -22.838000 -20.469200
# 43  -4.384091 -12.110909 -20.853273 -16.111000
# 44  -5.630303 -14.977455 -24.698545 -16.792400
# 45  -0.651768  -8.972879 -25.730152 -16.371833

# %%
# df_train.to_csv('~/Documents/GitHub/data/training_set.csv', index = False)

# %%
# df_train = pd.read_csv('~/Documents/GitHub/data/training_set_02252020.csv')

# groups = ['Bacteria','Red algae','Brown algae','Cyanobacteria','Diatom','Coccolithophore','Chlorophyte','Seagrasses']
# df_train = df_train[df_train.Feature.isin(groups)] # Drop unwanted groups
# df_train = df_train.reset_index()

# df_train

# %%
# PCA
# Separating out the features
features = ['Phe', 'Thr', 'Ile', 'Leu', 'Val']

x = df_pca.loc[:, features].values
xmean = x.mean(axis=1, keepdims = True)
x = x - xmean # Normalize to the mean of each row

# Separating out the target
y = df_pca.loc[:,['Feature']].values
# Standardizing the features
x = StandardScaler(with_std=True, with_mean=True).fit_transform(x)

pca = PCA(n_components=4)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents, 
                           columns = ['principal component 1', 'principal component 2', 
                                      'principal component 3', 'principal component 4'])

# %%
# principalDf

# %%
finalDf = pd.concat([principalDf, df_pca[['Feature']]], axis = 1)
# print(finalDf)

finalDf['Feature'].unique()
# Out:
# array(['Macroalgae', 'Microalgae', 'Cyanobacteria', 'Leiopathes-post',
#        'Leiopathes-pre'], dtype=object)

# %%
# 2D visualization
# Visualize 2D
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
ax.set_xlim(-4,6)
ax.set_ylim(-4,4)
targets = ['Leiopathes-pre', 'Leiopathes-post','Microalgae', 'Cyanobacteria', 'Macroalgae']
colors = ["#999999", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]
markers = ['o', 'o','v', '^', 'v', '>',]
for target, color, marker in zip(targets,colors,markers):
    indicesToKeep = finalDf['Feature'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 150,
              linewidths=0.75,
              edgecolors = 'k',
              linestyle = 'None',
              marker = marker)
    plt.grid('None')
ax.legend(targets, frameon = False)
ax.grid()

# Save figure
plt.savefig('pca_d13c.png', dpi=300, bbox_inches='tight')
