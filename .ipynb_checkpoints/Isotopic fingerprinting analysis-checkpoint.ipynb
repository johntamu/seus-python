# %% [markdown]
# ## Isotopic fingerprinting analysis

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
# Import data
df = pd.read_csv('~/Documents/GitHub/data/schiff c-csiaa data from schiff_larsen_in prog.csv')

# %%
corals = df[df['Group ID2'] == 'Leiopathes']
corals
# Out:
#           Group ID   Group ID2        Group ID3 Group ID4        Group ID5  \
# 131    STET-4904 7  Leiopathes  Leiopathes-post       NaN  Leiopathes-post
# 132    STET-4904 8  Leiopathes  Leiopathes-post       NaN  Leiopathes-post
# 133   STET-4904 22  Leiopathes  Leiopathes-post       NaN  Leiopathes-post
# 134   STET-4904 25  Leiopathes  Leiopathes-post       NaN  Leiopathes-post
# 135   STET-4904 40  Leiopathes   Leiopathes-pre       NaN   Leiopathes-pre
# 136   STET-4904 46  Leiopathes   Leiopathes-pre       NaN   Leiopathes-pre
# 137  STET-4904 103  Leiopathes   Leiopathes-pre       NaN   Leiopathes-pre
# 138  STET-4904 109  Leiopathes   Leiopathes-pre       NaN   Leiopathes-pre
# 139  STET-4904 135  Leiopathes   Leiopathes-pre       NaN   Leiopathes-pre
# 140  STET-4904 170  Leiopathes   Leiopathes-pre       NaN   Leiopathes-pre
#
#      Source       Region   Bulk        Ala  Ala.sd  ...  Met.sd        Phe  \
# 131  Schiff  Gulf Stream -16.99 -14.987193     NaN  ...     NaN -19.623750
# 132  Schiff  Gulf Stream -16.51 -15.675000     NaN  ...     NaN -21.996354
# 133  Schiff  Gulf Stream -15.79 -13.507895     NaN  ...     NaN -19.587812
# 134  Schiff  Gulf Stream -15.84 -15.106360     NaN  ...     NaN -22.747031
# 135  Schiff  Gulf Stream -15.31 -13.953684     NaN  ...     NaN -21.797734
# 136  Schiff  Gulf Stream -15.39 -16.468860     NaN  ...     NaN -20.357031
# 137  Schiff  Gulf Stream -15.58 -14.995614     NaN  ...     NaN -21.560859
# 138  Schiff  Gulf Stream -15.39 -13.162500     NaN  ...     NaN -19.111016
# 139  Schiff  Gulf Stream -15.57 -13.617895     NaN  ...     NaN -22.362500
# 140  Schiff  Gulf Stream -15.72 -18.261404     NaN  ...     NaN -21.988047
#
#      Phe.sd       Thr  Thr.sd        Tyr  Tyr.sd        Val  Val.sd  Year CE
# 131     NaN -7.448889     NaN -20.445104     NaN -15.392533     NaN   1977.0
# 132     NaN -1.860000     NaN -23.959375     NaN -16.709400     NaN   1973.0
# 133     NaN -4.630303     NaN -20.636198     NaN -15.469500     NaN   1915.0
# 134     NaN -5.781667     NaN -18.784297     NaN -16.270700     NaN   1902.0
# 135     NaN -0.220303     NaN -17.770703     NaN -15.897200     NaN   1841.0
# 136     NaN  1.686869     NaN -18.124089     NaN -16.711833     NaN   1817.0
# 137     NaN -4.580303     NaN -20.032552     NaN -20.469200     NaN   1583.0
# 138     NaN -4.384091     NaN -19.248281     NaN -16.111000     NaN   1559.0
# 139     NaN -5.630303     NaN -19.091771     NaN -16.792400     NaN   1451.0
# 140     NaN -0.651768     NaN -19.822396     NaN -16.371833     NaN   1309.0
#
# [10 rows x 39 columns]
